# %%
# Ur Usual imports
import os
import glob
import numpy as np

# Data/Data Augmentation/Visualization
import matplotlib as plt

# Neural Network Imports (we are using keras/Tensorflow, we can switch to Pytorch if u want...)
import tensorflow as tf

# %% [markdown]
# # Quick Overview of Google Data

# %%
# Make sure that kaggle is downloaded in your BASE environment if you are using an anaconda env
# Make sure to follow the Kaggle API Docs: https://github.com/Kaggle/kaggle-api

# !kaggle competitions files -c google-research-identify-contrails-reduce-global-warming
# Out:
# name                                                   size  creationDate
# ----------------------------------------------------  -----  -------------------
# validation/1073716558342302517/band_16.npy              2MB  2023-05-06 10:17:52
# validation/1073716558342302517/band_08.npy              2MB  2023-05-06 10:17:52
# validation/1073716558342302517/human_pixel_masks.npy  256KB  2023-05-06 10:17:52
# validation/1073716558342302517/band_12.npy              2MB  2023-05-06 10:17:52
# validation/1073716558342302517/band_14.npy              2MB  2023-05-06 10:17:52
# validation/1073716558342302517/band_13.npy              2MB  2023-05-06 10:17:52
# validation/1073716558342302517/band_09.npy              2MB  2023-05-06 10:17:52
# validation/1073716558342302517/band_15.npy              2MB  2023-05-06 10:17:52
# validation/1073716558342302517/band_11.npy              2MB  2023-05-06 10:17:52
# validation/1073716558342302517/band_10.npy              2MB  2023-05-06 10:17:52
# ...

# %% [markdown]
# # Downloads

# %% [markdown]
# RUN THIS ONLY IN THE BU SCC OTHERWISE GOOD LUCK WITH 340 GB OF INFORMATION!
# <br>
# <br>
# Later used to upload to google drive...

# %%
# !kaggle competitions download -c google-research-identify-contrails-reduce-global-warming

# %% [markdown]
# # Data Utility and Kaggle API Import

# %% [markdown]
# Uhhhhh, the dataset for Google's Contrail is like 480 GB of numpy arrays sooo we are using the kaggle API to bit chunk load it into a notebook lol.
